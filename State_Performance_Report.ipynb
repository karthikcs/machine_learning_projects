# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikcs/machine_learning_projects/blob/master/State_Performance_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## State performance report from Educational department
# ### Data [URL]
# https://inventory.data.gov/dataset/e4b3ce38-c0e2-45c1-97b4-73f6a467e801/resource/7c9a1737-5501-492a-8d23-99e1501e9e0b/download/userssharedsdfleaachvrsltsassessrlasy201112.csv

# %%
import pandas as pd
import numpy as np

# %%
input_file = 'https://inventory.data.gov/dataset/e4b3ce38-c0e2-45c1-97b4-73f6a467e801/resource/7c9a1737-5501-492a-8d23-99e1501e9e0b/download/userssharedsdfleaachvrsltsassessrlasy201112.csv'
df = pd.read_csv(input_file)

# %% [markdown]
# The dataset contains 16,060 records

# %%
df.shape
# Out:
# (16060, 228)

# %%
df.head()
# Out:
#      STNAM  FIPST  ...  MIG_RLAHSnumvalid_1112 MIG_RLAHSpctprof_1112
# 0  ALABAMA      1  ...                     NaN                   NaN
# 1  ALABAMA      1  ...                     3.0                    PS
# 2  ALABAMA      1  ...                     3.0                    PS
# 3  ALABAMA      1  ...                     NaN                   NaN
# 4  ALABAMA      1  ...                     NaN                   NaN
#
# [5 rows x 228 columns]
